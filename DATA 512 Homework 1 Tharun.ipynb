# %% [markdown]
# # Step 1: Data Acquisition
# In order to measure article traffic from 2015-2022, you will need to collect data from the Pageviews API. The Pageviews API (documentation, endpoint) provides access to desktop, mobile web, and mobile app traffic data from July 2015 through the previous complete month.
#
# You will be collecting counts of pageviews using a specified subset of Wikipedia article pages. This is a subset of the English Wikipedia that represents a large number of dinosaur related articles.
#
# You will use the same article subset to generate several related data sets. All of the data sets are time series of monthly activity. For all of the data sets we are only interested in actual user pageview requests. The three resulting datasets should be saved as a JSON files ordered using article titles as a key for the resulting time series data. You should store the time series data as returned from the API, with the exception of removing the ‘access’ field as it is misleading for mobile and cumulative files.

# %% [markdown]
# ## Step 1a - Configure the API request endpoints
#
# Provide the request header and parameters with dynamic values for access and article.

# %% [markdown]
# ### Import the required packages
#
# Importing the packages for extraction, transformation, plotting the data

# %%
# These are standard python modules
import json, time, urllib.parse
import pandas as pd
import numpy as np
import re
import requests
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ### Configure the endpoint details
#
# All the endpoint details, headers and parameters are configured below. The titles of the articles are extracted from the dinosaur excel sheet provided which contains 1423 unique articles.

# %%
# This is just a list of dinosaur Wikipedia article titles that we can use for example requests
dinosaurs_raw = pd.read_excel('dinosaur_genera.cleaned.SEPT.2022.xlsx')
ARTICLE_TITLES = dinosaurs_raw['name'].to_list()

# The REST API 'pageviews' URL - this is the common URL/endpoint for all 'pageviews' API requests
API_REQUEST_PAGEVIEWS_ENDPOINT = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/'

# This is a parameterized string that specifies what kind of pageviews request we are going to make
# In this case it will be a 'per-article' based request. The string is a format string so that we can
# replace each parameter with an appropriate value before making the request
API_REQUEST_PER_ARTICLE_PARAMS = 'per-article/{project}/{access}/{agent}/{article}/{granularity}/{start}/{end}'

# The Pageviews API asks that we not exceed 100 requests per second, we add a small delay to each request
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making a request to the Wikimedia API they ask that you include a "unique ID" that will allow them to
# contact you if something happens - such as - your code exceeding request limits - or some other error happens
REQUEST_HEADERS = {
    'User-Agent': '<karasth@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2022',
}

# REST API parameters for the json data blob from the website
ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE = {
    "project":     "en.wikipedia.org",
    "access":      "desktop",      # this should be changed for the different access types
    "agent":       "user",
    "article":     "",             # this value will be set/changed before each request
    "granularity": "monthly",
    "start":       "2015070100",   # this is the provided start date
    "end":         "2022093000"    # this is the provided end date
}

# %% [markdown]
# ### Function for REST API call to get the article related information
#
# Steps involved in the functione execution:
# 1. Pass the header, parameters and endpoint details for the GET request
# 2. Trigger the REST API GET request for each of the article and access type combination
# 3. Catch the exceptions where we couldn't extract the data from the endpoint

# %%
def request_pageviews_per_article(article_title = None, 
                                  endpoint_url = API_REQUEST_PAGEVIEWS_ENDPOINT, 
                                  endpoint_params = API_REQUEST_PER_ARTICLE_PARAMS, 
                                  request_template = ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE,
                                  headers = REQUEST_HEADERS):
    # Make sure we have an article title
    if not article_title: return None
    
    # Titles are supposed to have spaces replaced with "_" and be URL encoded
    article_title_encoded = urllib.parse.quote(article_title.replace(' ','_'))
    request_template['article'] = article_title_encoded
    
    # now, create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_params.format(**request_template)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %% [markdown]
# ## Step 1b - Extract the wikipedia information for the given dinosaur article names
#
# This step involves extracting the data for all the dinosaurs and all access types.

# %% [markdown]
# ### Extract the wikipedia article information for various access types (Desktop, Mobile, All)
#
# Added exception handling to highlight the articles for which we couldn't pull the information using the API endpoint

# %%
access_list = ['all-access', 'desktop', 'mobile-app', 'mobile-web']
df_access = list()
for i in ARTICLE_TITLES:
  # Exception handling to make sure code doesn't break
  try:
    for j in access_list:
      ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE['access'] = j
      views = request_pageviews_per_article(article_title = i, request_template = ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE)
      df_access.append(pd.json_normalize(views['items']))
    #print("Obtained the pageview data for: ",i)
  except:
    print("Couldn't get the pageview data for: ",i)

# Obtain the overall dinosaurs data
df_dinosaurs = pd.concat(df_access)
# Out:
# Couldn't get the pageview data for:  "Coelosaurus" antiquus
# Couldn't get the pageview data for:  Aachenosaurus
# Couldn't get the pageview data for:  Aardonyx
# Couldn't get the pageview data for:  Abdarainurus
# Couldn't get the pageview data for:  Abditosaurus
# Couldn't get the pageview data for:  Abelisaurus
# Couldn't get the pageview data for:  Abrictosaurus
# Couldn't get the pageview data for:  Abrosaurus
# Couldn't get the pageview data for:  Abydosaurus
# Couldn't get the pageview data for:  Acantholipan
# Couldn't get the pageview data for:  Acanthopholis
# Couldn't get the pageview data for:  Achelousaurus
# Couldn't get the pageview data for:  Acheroraptor
# Couldn't get the pageview data for:  Achillesaurus
# Couldn't get the pageview data for:  Achillobator
# Couldn't get the pageview data for:  Acristavus
# Couldn't get the pageview data for:  Acrocanthosaurus
# Couldn't get the pageview data for:  Acrotholus
# Couldn't get the pageview data for:  Actiosaurus
# Couldn't get the pageview data for:  Adamantisaurus
# Couldn't get the pageview data for:  Adasaurus
# Couldn't get the pageview data for:  Adelolophus
# Couldn't get the pageview data for:  Adeopapposaurus
# Couldn't get the pageview data for:  Adratiklit
# Couldn't get the pageview data for:  Adynomosaurus
# Couldn't get the pageview data for:  Aegyptosaurus
# Couldn't get the pageview data for:  Aeolosaurus
# Couldn't get the pageview data for:  Aepisaurus
# Couldn't get the pageview data for:  Aepyornithomimus
# Couldn't get the pageview data for:  Aerosteon
# Couldn't get the pageview data for:  Afromimus
# Couldn't get the pageview data for:  Afrovenator
# Couldn't get the pageview data for:  Agathaumas
# Couldn't get the pageview data for:  Aggiosaurus
# Couldn't get the pageview data for:  Agilisaurus
# Couldn't get the pageview data for:  Agnosphitys
# Couldn't get the pageview data for:  Agrosaurus
# Couldn't get the pageview data for:  Agujaceratops
# Couldn't get the pageview data for:  Agustinia
# Couldn't get the pageview data for:  Ahshislepelta
# Couldn't get the pageview data for:  Ajkaceratops
# Couldn't get the pageview data for:  Ajnabia
# Couldn't get the pageview data for:  Akainacephalus
# Couldn't get the pageview data for:  Alamosaurus
# Couldn't get the pageview data for:  Alaskacephale
# Couldn't get the pageview data for:  Albalophosaurus
# Couldn't get the pageview data for:  Albertaceratops
# Couldn't get the pageview data for:  Albertadromeus
# Couldn't get the pageview data for:  Albertavenator
# Couldn't get the pageview data for:  Albertonykus
# Couldn't get the pageview data for:  Albertosaurus
# Couldn't get the pageview data for:  Albinykus
# Couldn't get the pageview data for:  Albisaurus
# Couldn't get the pageview data for:  Alcovasaurus
# Couldn't get the pageview data for:  Alectrosaurus
# Couldn't get the pageview data for:  Aletopelta
# Couldn't get the pageview data for:  Algoasaurus
# Couldn't get the pageview data for:  Alioramus
# Couldn't get the pageview data for:  Allosaurus
# Couldn't get the pageview data for:  Almas ukhaa
# Couldn't get the pageview data for:  Alnashetri
# Couldn't get the pageview data for:  Alocodon
# Couldn't get the pageview data for:  Altirhinus
# Couldn't get the pageview data for:  Altispinax
# Couldn't get the pageview data for:  Alvarezsaurus
# Couldn't get the pageview data for:  Alwalkeria
# Couldn't get the pageview data for:  Alxasaurus
# Couldn't get the pageview data for:  Amanzia
# Couldn't get the pageview data for:  Amargasaurus
# Couldn't get the pageview data for:  Amargatitanis
# Couldn't get the pageview data for:  Amazonsaurus
# Couldn't get the pageview data for:  Ambopteryx
# Couldn't get the pageview data for:  Ampelosaurus
# Couldn't get the pageview data for:  Amphicoelias
# Couldn't get the pageview data for:  Amtocephale
# Couldn't get the pageview data for:  Amtosaurus
# Couldn't get the pageview data for:  Amurosaurus
# Couldn't get the pageview data for:  Amygdalodon
# Couldn't get the pageview data for:  Anabisetia
# Couldn't get the pageview data for:  Analong
# Couldn't get the pageview data for:  Anasazisaurus
# Couldn't get the pageview data for:  Anchiceratops
# Couldn't get the pageview data for:  Anchiornis
# Couldn't get the pageview data for:  Anchisaurus
# Couldn't get the pageview data for:  Andesaurus
# Couldn't get the pageview data for:  Angolatitan
# Couldn't get the pageview data for:  Angulomastacator
# Couldn't get the pageview data for:  Anhuilong
# Couldn't get the pageview data for:  Aniksosaurus
# Couldn't get the pageview data for:  Animantarx
# Couldn't get the pageview data for:  Ankistrodon
# Couldn't get the pageview data for:  Ankylosauria
# Couldn't get the pageview data for:  Ankylosaurus
# Couldn't get the pageview data for:  Anodontosaurus
# Couldn't get the pageview data for:  Anomalipes
# Couldn't get the pageview data for:  Anoplosaurus
# Couldn't get the pageview data for:  Anserimimus
# Couldn't get the pageview data for:  Antarctopelta
# Couldn't get the pageview data for:  Antarctosaurus
# Couldn't get the pageview data for:  Antetonitrus
# Couldn't get the pageview data for:  Antrodemus
# Couldn't get the pageview data for:  Anzu wyliei
# Couldn't get the pageview data for:  Aoniraptor
# Couldn't get the pageview data for:  Aorun
# Couldn't get the pageview data for:  Apatodon
# Couldn't get the pageview data for:  Apatoraptor
# Couldn't get the pageview data for:  Apatosaurus
# Couldn't get the pageview data for:  Appalachiosaurus
# Couldn't get the pageview data for:  Aquilarhinus
# Couldn't get the pageview data for:  Aquilops
# Couldn't get the pageview data for:  Arackar
# Couldn't get the pageview data for:  Aragosaurus
# Couldn't get the pageview data for:  Aralosaurus
# Couldn't get the pageview data for:  Aratasaurus
# Couldn't get the pageview data for:  Archaeoceratops
# Couldn't get the pageview data for:  Archaeodontosaurus
# Couldn't get the pageview data for:  Archaeopteryx
# Couldn't get the pageview data for:  Archaeoraptor
# Couldn't get the pageview data for:  Archaeornithoides
# Couldn't get the pageview data for:  Archaeornithomimus
# Couldn't get the pageview data for:  Archosaur
# Couldn't get the pageview data for:  Arcovenator
# Couldn't get the pageview data for:  Arctosaurus
# Couldn't get the pageview data for:  Arcusaurus
# Couldn't get the pageview data for:  Arenysaurus
# Couldn't get the pageview data for:  Argentinosaurus
# Couldn't get the pageview data for:  Argyrosaurus
# Couldn't get the pageview data for:  Aristosuchus
# Couldn't get the pageview data for:  Arizonasaurus
# Couldn't get the pageview data for:  Arkansaurus
# Couldn't get the pageview data for:  Arkharavia
# Couldn't get the pageview data for:  Arrhinoceratops
# Couldn't get the pageview data for:  Arrudatitan
# Couldn't get the pageview data for:  Arstanosaurus
# Couldn't get the pageview data for:  Asfaltovenator
# Couldn't get the pageview data for:  Asiaceratops
# Couldn't get the pageview data for:  Asiamericana
# Couldn't get the pageview data for:  Asiatosaurus
# Couldn't get the pageview data for:  Asilisaurus
# Couldn't get the pageview data for:  Astrodon
# Couldn't get the pageview data for:  Astrophocaudia
# Couldn't get the pageview data for:  Asylosaurus
# Couldn't get the pageview data for:  Atacamatitan
# Couldn't get the pageview data for:  Atlantosaurus
# Couldn't get the pageview data for:  Atlasaurus
# Couldn't get the pageview data for:  Atlascopcosaurus
# Couldn't get the pageview data for:  Atrociraptor
# Couldn't get the pageview data for:  Atsinganosaurus
# Couldn't get the pageview data for:  Aublysodon
# Couldn't get the pageview data for:  Aucasaurus
# Couldn't get the pageview data for:  Augustynolophus
# Couldn't get the pageview data for:  Auroraceratops
# Couldn't get the pageview data for:  Aurornis
# Couldn't get the pageview data for:  Australodocus
# Couldn't get the pageview data for:  Australotitan
# Couldn't get the pageview data for:  Australovenator
# Couldn't get the pageview data for:  Austrocheirus
# Couldn't get the pageview data for:  Austroposeidon
# Couldn't get the pageview data for:  Austroraptor
# Couldn't get the pageview data for:  Austrosaurus
# Couldn't get the pageview data for:  Avaceratops
# Couldn't get the pageview data for:  Avalonianus
# Couldn't get the pageview data for:  Avebrevicauda
# Couldn't get the pageview data for:  Avemetatarsalia
# Couldn't get the pageview data for:  Aviatyrannis
# Couldn't get the pageview data for:  Avimimus
# Couldn't get the pageview data for:  Avipes
# Couldn't get the pageview data for:  Avisaurus
# Couldn't get the pageview data for:  Azendohsaurus
# Couldn't get the pageview data for:  Azhdarchoidea
# Couldn't get the pageview data for:  Baalsaurus
# Couldn't get the pageview data for:  Bactrosaurus
# Couldn't get the pageview data for:  Bagaceratops
# Couldn't get the pageview data for:  Bagaraatan
# Couldn't get the pageview data for:  Bagualia
# Couldn't get the pageview data for:  Bagualosaurus
# Couldn't get the pageview data for:  Bahariasaurus
# Couldn't get the pageview data for:  Bainoceratops
# Couldn't get the pageview data for:  Bajadasaurus
# Couldn't get the pageview data for:  Balaur bondoc
# Couldn't get the pageview data for:  Bambiraptor
# Couldn't get the pageview data for:  Banji
# Couldn't get the pageview data for:  Bannykus
# Couldn't get the pageview data for:  Baotianmansaurus
# Couldn't get the pageview data for:  Barapasaurus
# Couldn't get the pageview data for:  Barilium
# Couldn't get the pageview data for:  Barosaurus
# Couldn't get the pageview data for:  Barrosasaurus
# Couldn't get the pageview data for:  Barsboldia
# Couldn't get the pageview data for:  Baryonyx
# Couldn't get the pageview data for:  Bashanosaurus
# Couldn't get the pageview data for:  Basutodon
# Couldn't get the pageview data for:  Batyrosaurus
# Couldn't get the pageview data for:  Baurutitan
# Couldn't get the pageview data for:  Bayannurosaurus
# Couldn't get the pageview data for:  Beg tse
# Couldn't get the pageview data for:  Beibeilong
# Couldn't get the pageview data for:  Beipiaognathus
# Couldn't get the pageview data for:  Beipiaosaurus
# Couldn't get the pageview data for:  Beishanlong
# Couldn't get the pageview data for:  Bellusaurus
# Couldn't get the pageview data for:  Belodon
# Couldn't get the pageview data for:  Berberosaurus
# Couldn't get the pageview data for:  Berthasaura
# Couldn't get the pageview data for:  Betasuchus
# Couldn't get the pageview data for:  Bicentenaria
# Couldn't get the pageview data for:  Bienosaurus
# Couldn't get the pageview data for:  Bissektipelta
# Couldn't get the pageview data for:  Bistahieversor
# Couldn't get the pageview data for:  Bisticeratops
# Couldn't get the pageview data for:  Blasisaurus
# Couldn't get the pageview data for:  Blikanasaurus
# Couldn't get the pageview data for:  Bolong
# Couldn't get the pageview data for:  Bonapartenykus
# Couldn't get the pageview data for:  Bonapartesaurus
# Couldn't get the pageview data for:  Bonatitan
# Couldn't get the pageview data for:  Bonitasaura
# Couldn't get the pageview data for:  Borealopelta
# Couldn't get the pageview data for:  Borealosaurus
# Couldn't get the pageview data for:  Boreonykus
# Couldn't get the pageview data for:  Borogovia
# Couldn't get the pageview data for:  Bothriospondylus
# Couldn't get the pageview data for:  Brachiosaurus
# Couldn't get the pageview data for:  Brachyceratops
# Couldn't get the pageview data for:  Brachylophosaurus
# Couldn't get the pageview data for:  Brachypodosaurus
# Couldn't get the pageview data for:  Brachytrachelopan
# Couldn't get the pageview data for:  Bradycneme
# Couldn't get the pageview data for:  Brasileosaurus
# Couldn't get the pageview data for:  Brasilotitan
# Couldn't get the pageview data for:  Bravasaurus
# Couldn't get the pageview data for:  Bravoceratops
# Couldn't get the pageview data for:  Breviceratops
# Couldn't get the pageview data for:  Brighstoneus
# Couldn't get the pageview data for:  Brithopus
# Couldn't get the pageview data for:  Brohisaurus
# Couldn't get the pageview data for:  Brontomerus
# Couldn't get the pageview data for:  Brontosaurus
# Couldn't get the pageview data for:  Bruhathkayosaurus
# Couldn't get the pageview data for:  Buitreraptor
# Couldn't get the pageview data for:  Burianosaurus
# Couldn't get the pageview data for:  Buriolestes
# Couldn't get the pageview data for:  Byronosaurus
# Couldn't get the pageview data for:  Caenagnathasia
# Couldn't get the pageview data for:  Caenagnathus
# Couldn't get the pageview data for:  Caihong
# Couldn't get the pageview data for:  Calamosaurus
# Couldn't get the pageview data for:  Calamospondylus
# Couldn't get the pageview data for:  Callovosaurus
# Couldn't get the pageview data for:  Camarasaurus
# Couldn't get the pageview data for:  Camarillasaurus
# Couldn't get the pageview data for:  Camelotia
# Couldn't get the pageview data for:  Camposaurus
# Couldn't get the pageview data for:  Camptosaurus
# Couldn't get the pageview data for:  Campylodoniscus
# Couldn't get the pageview data for:  Canardia
# Couldn't get the pageview data for:  Carcharodontosaurus
# Couldn't get the pageview data for:  Cardiodon
# Couldn't get the pageview data for:  Carnotaurus
# Couldn't get the pageview data for:  Caseosaurus
# Couldn't get the pageview data for:  Cathartesaura
# Couldn't get the pageview data for:  Caudipteryx
# Couldn't get the pageview data for:  Cedarosaurus
# Couldn't get the pageview data for:  Cedarpelta
# Couldn't get the pageview data for:  Cedrorestes
# Couldn't get the pageview data for:  Centemodon
# Couldn't get the pageview data for:  Centrosaurus
# Couldn't get the pageview data for:  Cerasinops
# Couldn't get the pageview data for:  Ceratonykus
# Couldn't get the pageview data for:  Ceratops
# Couldn't get the pageview data for:  Ceratosaurus
# Couldn't get the pageview data for:  Ceratosuchops
# Couldn't get the pageview data for:  Cetiosauriscus
# Couldn't get the pageview data for:  Cetiosaurus
# Couldn't get the pageview data for:  Changchunsaurus
# Couldn't get the pageview data for:  Changmiania
# Couldn't get the pageview data for:  Changyuraptor
# Couldn't get the pageview data for:  Chaoyangsaurus
# Couldn't get the pageview data for:  Charonosaurus
# Couldn't get the pageview data for:  Chasmosaurus
# Couldn't get the pageview data for:  Chebsaurus
# Couldn't get the pageview data for:  Chenanisaurus
# Couldn't get the pageview data for:  Chialingosaurus
# Couldn't get the pageview data for:  Chiayusaurus
# Couldn't get the pageview data for:  Chienkosaurus
# Couldn't get the pageview data for:  Chilantaisaurus
# Couldn't get the pageview data for:  Chilesaurus
# Couldn't get the pageview data for:  Chindesaurus
# Couldn't get the pageview data for:  Chingkankousaurus
# Couldn't get the pageview data for:  Chinshakiangosaurus
# Couldn't get the pageview data for:  Chirostenotes
# Couldn't get the pageview data for:  Choconsaurus
# Couldn't get the pageview data for:  Chondrosteosaurus
# Couldn't get the pageview data for:  Choyrodon
# Couldn't get the pageview data for:  Chromogisaurus
# Couldn't get the pageview data for:  Chuandongocoelurus
# Couldn't get the pageview data for:  Chuanjiesaurus
# Couldn't get the pageview data for:  Chuanqilong
# Couldn't get the pageview data for:  Chubutisaurus
# Couldn't get the pageview data for:  Chungkingosaurus
# Couldn't get the pageview data for:  Chuxiongosaurus
# Couldn't get the pageview data for:  Cionodon
# Couldn't get the pageview data for:  Citipati
# Couldn't get the pageview data for:  Citipes
# Couldn't get the pageview data for:  Claorhynchus
# Couldn't get the pageview data for:  Claosaurus
# Couldn't get the pageview data for:  Clasmodosaurus
# Couldn't get the pageview data for:  Clepsysaurus
# Couldn't get the pageview data for:  Coahuilaceratops
# Couldn't get the pageview data for:  Coelophysis
# Couldn't get the pageview data for:  Coeluroides
# Couldn't get the pageview data for:  Coelurosauravus
# Couldn't get the pageview data for:  Coelurus
# Couldn't get the pageview data for:  Colepiocephale
# Couldn't get the pageview data for:  Coloradisaurus
# Couldn't get the pageview data for:  Comahuesaurus
# Couldn't get the pageview data for:  Compsognathus
# Couldn't get the pageview data for:  Compsosuchus
# Couldn't get the pageview data for:  Concavenator
# Couldn't get the pageview data for:  Conchoraptor
# Couldn't get the pageview data for:  Condorraptor
# Couldn't get the pageview data for:  Convolosaurus
# Couldn't get the pageview data for:  Coronosaurus
# Couldn't get the pageview data for:  Corythoraptor
# Couldn't get the pageview data for:  Corythosaurus
# Couldn't get the pageview data for:  Craspedodon
# Couldn't get the pageview data for:  Craterosaurus
# Couldn't get the pageview data for:  Crichtonpelta
# Couldn't get the pageview data for:  Crichtonsaurus
# Couldn't get the pageview data for:  Cristatusaurus
# Couldn't get the pageview data for:  Crittendenceratops
# Couldn't get the pageview data for:  Crocodilia
# Couldn't get the pageview data for:  Crosbysaurus
# Couldn't get the pageview data for:  Crurotarsi
# Couldn't get the pageview data for:  Cruxicheiros
# Couldn't get the pageview data for:  Cryolophosaurus
# Couldn't get the pageview data for:  Cryptosaurus
# Couldn't get the pageview data for:  Cumnoria
# Couldn't get the pageview data for:  Daanosaurus
# Couldn't get the pageview data for:  Dacentrurus
# Couldn't get the pageview data for:  Daemonosaurus
# Couldn't get the pageview data for:  Dahalokely
# Couldn't get the pageview data for:  Dakosaurus
# Couldn't get the pageview data for:  Dakotadon
# Couldn't get the pageview data for:  Dakotaraptor
# Couldn't get the pageview data for:  Daliansaurus
# Couldn't get the pageview data for:  Dandakosaurus
# Couldn't get the pageview data for:  Dashanpusaurus
# Couldn't get the pageview data for:  Daspletosaurus
# Couldn't get the pageview data for:  Dasygnathoides
# Couldn't get the pageview data for:  Datanglong
# Couldn't get the pageview data for:  Datonglong
# Couldn't get the pageview data for:  Datousaurus
# Couldn't get the pageview data for:  Daxiatitan
# Couldn't get the pageview data for:  Deinocheirus
# Couldn't get the pageview data for:  Deinodon
# Couldn't get the pageview data for:  Deinonychus
# Couldn't get the pageview data for:  Deltadromeus
# Couldn't get the pageview data for:  Demandasaurus
# Couldn't get the pageview data for:  Denversaurus
# Couldn't get the pageview data for:  Deuterosaurus
# Couldn't get the pageview data for:  Diabloceratops
# Couldn't get the pageview data for:  Diamantinasaurus
# Couldn't get the pageview data for:  Dianchungosaurus
# Couldn't get the pageview data for:  Diapsid
# Couldn't get the pageview data for:  Diclonius
# Couldn't get the pageview data for:  Dicraeosaurus
# Couldn't get the pageview data for:  Dilong paradoxus
# Couldn't get the pageview data for:  Dilophosaurus
# Couldn't get the pageview data for:  Diluvicursor
# Couldn't get the pageview data for:  Dimetrodon
# Couldn't get the pageview data for:  Dineobellator
# Couldn't get the pageview data for:  Dinheirosaurus
# Couldn't get the pageview data for:  Dinodocus
# Couldn't get the pageview data for:  Diplodocus
# Couldn't get the pageview data for:  Diplotomodon
# Couldn't get the pageview data for:  Dolichosuchus
# Couldn't get the pageview data for:  Dongbeititan
# Couldn't get the pageview data for:  Dongyangopelta
# Couldn't get the pageview data for:  Dongyangosaurus
# Couldn't get the pageview data for:  Doratodon
# Couldn't get the pageview data for:  Draconyx
# Couldn't get the pageview data for:  Dracopelta
# Couldn't get the pageview data for:  Dracoraptor
# Couldn't get the pageview data for:  Dracovenator
# Couldn't get the pageview data for:  Dravidosaurus
# Couldn't get the pageview data for:  Dreadnoughtus
# Couldn't get the pageview data for:  Dromaeosauroides
# Couldn't get the pageview data for:  Dromaeosaurus
# Couldn't get the pageview data for:  Dromiceiomimus
# Couldn't get the pageview data for:  Drusilasaura
# Couldn't get the pageview data for:  Dryosaurus
# Couldn't get the pageview data for:  Dryptosauroides
# Couldn't get the pageview data for:  Dryptosaurus
# Couldn't get the pageview data for:  Dubreuillosaurus
# Couldn't get the pageview data for:  Duriatitan
# Couldn't get the pageview data for:  Duriavenator
# Couldn't get the pageview data for:  Dynamoterror
# Couldn't get the pageview data for:  Dyoplosaurus
# Couldn't get the pageview data for:  Dysalotosaurus
# Couldn't get the pageview data for:  Dysganus
# Couldn't get the pageview data for:  Dyslocosaurus
# Couldn't get the pageview data for:  Dystrophaeus
# Couldn't get the pageview data for:  Dzharaonyx
# Couldn't get the pageview data for:  Dzharatitanis
# Couldn't get the pageview data for:  Echinodon
# Couldn't get the pageview data for:  Edmontonia
# Couldn't get the pageview data for:  Edmontosaurus
# Couldn't get the pageview data for:  Efraasia
# Couldn't get the pageview data for:  Einiosaurus
# Couldn't get the pageview data for:  Ekrixinatosaurus
# Couldn't get the pageview data for:  Elachistosuchus
# Couldn't get the pageview data for:  Elaltitan
# Couldn't get the pageview data for:  Elaphrosaurus
# Couldn't get the pageview data for:  Elemgasem
# Couldn't get the pageview data for:  Elmisaurus
# Couldn't get the pageview data for:  Elopteryx
# Couldn't get the pageview data for:  Elrhazosaurus
# Couldn't get the pageview data for:  Emausaurus
# Couldn't get the pageview data for:  Embasaurus
# Couldn't get the pageview data for:  Enigmosaurus
# Couldn't get the pageview data for:  Eoabelisaurus
# Couldn't get the pageview data for:  Eocarcharia
# Couldn't get the pageview data for:  Eocursor
# Couldn't get the pageview data for:  Eodromaeus
# Couldn't get the pageview data for:  Eolambia
# Couldn't get the pageview data for:  Eomamenchisaurus
# Couldn't get the pageview data for:  Eoraptor
# Couldn't get the pageview data for:  Eosinopteryx
# Couldn't get the pageview data for:  Eotrachodon
# Couldn't get the pageview data for:  Eotriceratops
# Couldn't get the pageview data for:  Eotyrannus
# Couldn't get the pageview data for:  Eousdryosaurus
# Couldn't get the pageview data for:  Epachthosaurus
# Couldn't get the pageview data for:  Epanterias
# Couldn't get the pageview data for:  Epichirostenotes
# Couldn't get the pageview data for:  Epidexipteryx
# Couldn't get the pageview data for:  Equijubus
# Couldn't get the pageview data for:  Erectopus
# Couldn't get the pageview data for:  Erketu
# Couldn't get the pageview data for:  Erliansaurus
# Couldn't get the pageview data for:  Erlikosaurus
# Couldn't get the pageview data for:  Erythrovenator
# Couldn't get the pageview data for:  Eshanosaurus
# Couldn't get the pageview data for:  Eucamerotus
# Couldn't get the pageview data for:  Eucercosaurus
# Couldn't get the pageview data for:  Eucnemesaurus
# Couldn't get the pageview data for:  Eucoelophysis
# Couldn't get the pageview data for:  Euhelopus
# Couldn't get the pageview data for:  Euoplocephalus
# Couldn't get the pageview data for:  Eurolimnornis
# Couldn't get the pageview data for:  Euronychodon
# Couldn't get the pageview data for:  Europasaurus
# Couldn't get the pageview data for:  Europatitan
# Couldn't get the pageview data for:  Europelta
# Couldn't get the pageview data for:  Euskelosaurus
# Couldn't get the pageview data for:  Eustreptospondylus
# Couldn't get the pageview data for:  Fabrosaurus
# Couldn't get the pageview data for:  Falcarius
# Couldn't get the pageview data for:  Ferganasaurus
# Couldn't get the pageview data for:  Ferganocephale
# Couldn't get the pageview data for:  Ferrisaurus
# Couldn't get the pageview data for:  Foraminacephale
# Couldn't get the pageview data for:  Fosterovenator
# Couldn't get the pageview data for:  Fostoria dhimbangunmal
# Couldn't get the pageview data for:  Fruitadens
# Couldn't get the pageview data for:  Fukuiraptor
# Couldn't get the pageview data for:  Fukuisaurus
# Couldn't get the pageview data for:  Fukuititan
# Couldn't get the pageview data for:  Fukuivenator
# Couldn't get the pageview data for:  Fulengia
# Couldn't get the pageview data for:  Fulgurotherium
# Couldn't get the pageview data for:  Fushanosaurus
# Couldn't get the pageview data for:  Fusuisaurus
# Couldn't get the pageview data for:  Futabasaurus
# Couldn't get the pageview data for:  Futalognkosaurus
# Couldn't get the pageview data for:  Fylax
# Couldn't get the pageview data for:  Galeamopus
# Couldn't get the pageview data for:  Galesaurus
# Couldn't get the pageview data for:  Galleonosaurus
# Couldn't get the pageview data for:  Gallimimus
# Couldn't get the pageview data for:  Galvesaurus
# Couldn't get the pageview data for:  Gannansaurus
# Couldn't get the pageview data for:  Ganzhousaurus
# Couldn't get the pageview data for:  Gargoyleosaurus
# Couldn't get the pageview data for:  Garrigatitan
# Couldn't get the pageview data for:  Garudimimus
# Couldn't get the pageview data for:  Gasosaurus
# Couldn't get the pageview data for:  Gasparinisaura
# Couldn't get the pageview data for:  Gastonia (dinosaur)
# Couldn't get the pageview data for:  Geminiraptor
# Couldn't get the pageview data for:  Genusaurus
# Couldn't get the pageview data for:  Genyodectes
# Couldn't get the pageview data for:  Geosaurus
# Couldn't get the pageview data for:  Geranosaurus
# Couldn't get the pageview data for:  Gideonmantellia
# Couldn't get the pageview data for:  Giganotosaurus
# Couldn't get the pageview data for:  Gigantoraptor
# Couldn't get the pageview data for:  Gigantosaurus
# Couldn't get the pageview data for:  Gigantoscelus
# Couldn't get the pageview data for:  Gigantspinosaurus
# Couldn't get the pageview data for:  Gilmoreosaurus
# Couldn't get the pageview data for:  Giraffatitan
# Couldn't get the pageview data for:  Glacialisaurus
# Couldn't get the pageview data for:  Glishades
# Couldn't get the pageview data for:  Glyptodontopelta
# Couldn't get the pageview data for:  Gnathovorax
# Couldn't get the pageview data for:  Gobihadros
# Couldn't get the pageview data for:  Gobiraptor
# Couldn't get the pageview data for:  Gobisaurus
# Couldn't get the pageview data for:  Gobititan
# Couldn't get the pageview data for:  Gobivenator
# Couldn't get the pageview data for:  Gojirasaurus
# Couldn't get the pageview data for:  Gondwanatitan
# Couldn't get the pageview data for:  Gongbusaurus
# Couldn't get the pageview data for:  Gongpoquansaurus
# Couldn't get the pageview data for:  Gongxianosaurus
# Couldn't get the pageview data for:  Gorgosaurus
# Couldn't get the pageview data for:  Goyocephale
# Couldn't get the pageview data for:  Graciliceratops
# Couldn't get the pageview data for:  Graciliraptor
# Couldn't get the pageview data for:  Gracilisuchus
# Couldn't get the pageview data for:  Gravitholus
# Couldn't get the pageview data for:  Gresslyosaurus
# Couldn't get the pageview data for:  Gryphoceratops
# Couldn't get the pageview data for:  Gryponyx
# Couldn't get the pageview data for:  Gryposaurus
# Couldn't get the pageview data for:  Guaibasaurus
# Couldn't get the pageview data for:  Gualicho
# Couldn't get the pageview data for:  Guanlong
# Couldn't get the pageview data for:  Guemesia
# Couldn't get the pageview data for:  Gwyneddosaurus
# Couldn't get the pageview data for:  Gyposaurus
# Couldn't get the pageview data for:  Hadrosaurus
# Couldn't get the pageview data for:  Haestasaurus
# Couldn't get the pageview data for:  Hagryphus
# Couldn't get the pageview data for:  Hallopus
# Couldn't get the pageview data for:  Halszkaraptor
# Couldn't get the pageview data for:  Halticosaurus
# Couldn't get the pageview data for:  Hamititan
# Couldn't get the pageview data for:  Hanssuesia
# Couldn't get the pageview data for:  Haplocanthosaurus
# Couldn't get the pageview data for:  Haplocheirus
# Couldn't get the pageview data for:  Harpymimus
# Couldn't get the pageview data for:  Haya griva
# Couldn't get the pageview data for:  Heishansaurus
# Couldn't get the pageview data for:  Helioceratops
# Couldn't get the pageview data for:  Heptasteornis
# Couldn't get the pageview data for:  Herbstosaurus
# Couldn't get the pageview data for:  Herrerasaurus
# Couldn't get the pageview data for:  Hesperonychus
# Couldn't get the pageview data for:  Hesperornithoides
# Couldn't get the pageview data for:  Hesperosaurus
# Couldn't get the pageview data for:  Heterodontosaurus
# Couldn't get the pageview data for:  Hexing
# Couldn't get the pageview data for:  Hexinlusaurus
# Couldn't get the pageview data for:  Heyuannia
# Couldn't get the pageview data for:  Hierosaurus
# Couldn't get the pageview data for:  Hippodraco
# Couldn't get the pageview data for:  Histriasaurus
# Couldn't get the pageview data for:  Homalocephale
# Couldn't get the pageview data for:  Honghesaurus
# Couldn't get the pageview data for:  Hoplitosaurus
# Couldn't get the pageview data for:  Horshamosaurus
# Couldn't get the pageview data for:  Hortalotarsus
# Couldn't get the pageview data for:  Huabeisaurus
# Couldn't get the pageview data for:  Hualianceratops
# Couldn't get the pageview data for:  Huallasaurus
# Couldn't get the pageview data for:  Huanansaurus
# Couldn't get the pageview data for:  Huanghetitan
# Couldn't get the pageview data for:  Huangshanlong
# Couldn't get the pageview data for:  Huaxiagnathus
# Couldn't get the pageview data for:  Huayangosaurus
# Couldn't get the pageview data for:  Hudiesaurus
# Couldn't get the pageview data for:  Huehuecanauhtlus
# Couldn't get the pageview data for:  Huinculsaurus
# Couldn't get the pageview data for:  Hulsanpes
# Couldn't get the pageview data for:  Hungarosaurus
# Couldn't get the pageview data for:  Hylaeosaurus
# Couldn't get the pageview data for:  Hypacrosaurus
# Couldn't get the pageview data for:  Hyperodapedon
# Couldn't get the pageview data for:  Hypselorhachis
# Couldn't get the pageview data for:  Hypselosaurus
# Couldn't get the pageview data for:  Hypselospinus
# Couldn't get the pageview data for:  Hypsibema
# Couldn't get the pageview data for:  Hypsibema missouriensis
# Couldn't get the pageview data for:  Hypsilophodon
# Couldn't get the pageview data for:  Hypsirhophus
# Couldn't get the pageview data for:  Iberospinus
# Couldn't get the pageview data for:  Ichthyosaur
# Couldn't get the pageview data for:  Ichthyovenator
# Couldn't get the pageview data for:  Ignavusaurus
# Couldn't get the pageview data for:  Ignotosaurus
# Couldn't get the pageview data for:  Iguanacolossus
# Couldn't get the pageview data for:  Iguanodon
# Couldn't get the pageview data for:  Iliosuchus
# Couldn't get the pageview data for:  Ilokelesia
# Couldn't get the pageview data for:  Imperobator
# Couldn't get the pageview data for:  Incisivosaurus
# Couldn't get the pageview data for:  Indosaurus
# Couldn't get the pageview data for:  Indosuchus
# Couldn't get the pageview data for:  Ingentia
# Couldn't get the pageview data for:  Inosaurus
# Couldn't get the pageview data for:  Invictarx
# Couldn't get the pageview data for:  Irisosaurus
# Couldn't get the pageview data for:  Irritator
# Couldn't get the pageview data for:  Isaberrysaura
# Couldn't get the pageview data for:  Isanosaurus
# Couldn't get the pageview data for:  Isasicursor
# Couldn't get the pageview data for:  Ischioceratops
# Couldn't get the pageview data for:  Isisaurus
# Couldn't get the pageview data for:  Issi
# Couldn't get the pageview data for:  Itapeuasaurus
# Couldn't get the pageview data for:  Itemirus
# Couldn't get the pageview data for:  Iuticosaurus
# Couldn't get the pageview data for:  Iyuku
# Couldn't get the pageview data for:  Jainosaurus
# Couldn't get the pageview data for:  Jakapil
# Couldn't get the pageview data for:  Jaklapallisaurus
# Couldn't get the pageview data for:  Janenschia
# Couldn't get the pageview data for:  Jaxartosaurus
# Couldn't get the pageview data for:  Jeholosaurus
# Couldn't get the pageview data for:  Jeyawati
# Couldn't get the pageview data for:  Jianchangosaurus
# Couldn't get the pageview data for:  Jiangjunosaurus
# Couldn't get the pageview data for:  Jiangshanosaurus
# Couldn't get the pageview data for:  Jiangxisaurus
# Couldn't get the pageview data for:  Jianianhualong
# Couldn't get the pageview data for:  Jinbeisaurus
# Couldn't get the pageview data for:  Jinfengopteryx
# Couldn't get the pageview data for:  Jingshanosaurus
# Couldn't get the pageview data for:  Jintasaurus
# Couldn't get the pageview data for:  Jinyunpelta
# Couldn't get the pageview data for:  Jinzhousaurus
# Couldn't get the pageview data for:  Jiutaisaurus
# Couldn't get the pageview data for:  Jobaria
# Couldn't get the pageview data for:  Jubbulpuria
# Couldn't get the pageview data for:  Judiceratops
# Couldn't get the pageview data for:  Juratyrant
# Couldn't get the pageview data for:  Juravenator
# Couldn't get the pageview data for:  Kaatedocus
# Couldn't get the pageview data for:  Kaijiangosaurus
# Couldn't get the pageview data for:  Kaijutitan
# Couldn't get the pageview data for:  Kakuru
# Couldn't get the pageview data for:  Kamuysaurus
# Couldn't get the pageview data for:  Kangnasaurus
# Couldn't get the pageview data for:  Kansaignathus
# Couldn't get the pageview data for:  Karongasaurus
# Couldn't get the pageview data for:  Katepensaurus
# Couldn't get the pageview data for:  Kayentavenator
# Couldn't get the pageview data for:  Kazaklambia
# Couldn't get the pageview data for:  Kelmayisaurus
# Couldn't get the pageview data for:  Kelumapusaura
# Couldn't get the pageview data for:  Kemkemia
# Couldn't get the pageview data for:  Kentrosaurus
# Couldn't get the pageview data for:  Kerberosaurus
# Couldn't get the pageview data for:  Khaan
# Couldn't get the pageview data for:  Kholumolumo
# Couldn't get the pageview data for:  Khulsanurus
# Couldn't get the pageview data for:  Kileskus
# Couldn't get the pageview data for:  Kinnareemimus
# Couldn't get the pageview data for:  Klamelisaurus
# Couldn't get the pageview data for:  Kol ghuva
# Couldn't get the pageview data for:  Koparion
# Couldn't get the pageview data for:  Koreaceratops
# Couldn't get the pageview data for:  Koreanosaurus
# Couldn't get the pageview data for:  Koshisaurus
# Couldn't get the pageview data for:  Kosmoceratops
# Couldn't get the pageview data for:  Kotasaurus
# Couldn't get the pageview data for:  Koutalisaurus
# Couldn't get the pageview data for:  Kritosaurus
# Couldn't get the pageview data for:  Kryptops
# Couldn't get the pageview data for:  Krzyzanowskisaurus
# Couldn't get the pageview data for:  Kulceratops
# Couldn't get the pageview data for:  Kulindadromeus
# Couldn't get the pageview data for:  Kunbarrasaurus
# Couldn't get the pageview data for:  Kundurosaurus
# Couldn't get the pageview data for:  Kuru kulla
# Couldn't get the pageview data for:  Kurupi itaata
# Couldn't get the pageview data for:  Kuszholia
# Couldn't get the pageview data for:  Kwanasaurus
# Couldn't get the pageview data for:  Labocania
# Couldn't get the pageview data for:  Laevisuchus
# Couldn't get the pageview data for:  Lagerpeton
# Couldn't get the pageview data for:  Lagosuchus
# Couldn't get the pageview data for:  Laiyangosaurus
# Couldn't get the pageview data for:  Lajasvenator
# Couldn't get the pageview data for:  Lambeosaurus
# Couldn't get the pageview data for:  Lametasaurus
# Couldn't get the pageview data for:  Lamplughsaura
# Couldn't get the pageview data for:  Lanzhousaurus
# Couldn't get the pageview data for:  Laosaurus
# Couldn't get the pageview data for:  Lapampasaurus
# Couldn't get the pageview data for:  Laplatasaurus
# Couldn't get the pageview data for:  Lapparentosaurus
# Couldn't get the pageview data for:  Laquintasaura
# Couldn't get the pageview data for:  Lariosaurus
# Couldn't get the pageview data for:  Latenivenatrix
# Couldn't get the pageview data for:  Latirhinus
# Couldn't get the pageview data for:  Lavocatisaurus
# Couldn't get the pageview data for:  Leaellynasaura
# Couldn't get the pageview data for:  Ledumahadi
# Couldn't get the pageview data for:  Leinkupal
# Couldn't get the pageview data for:  Leonerasaurus
# Couldn't get the pageview data for:  Lepidus praecisio
# Couldn't get the pageview data for:  Leptoceratops
# Couldn't get the pageview data for:  Leshansaurus
# Couldn't get the pageview data for:  Lesothosaurus
# Couldn't get the pageview data for:  Lessemsaurus
# Couldn't get the pageview data for:  Levnesovia
# Couldn't get the pageview data for:  Lewisuchus
# Couldn't get the pageview data for:  Lexovisaurus
# Couldn't get the pageview data for:  Leyesaurus
# Couldn't get the pageview data for:  Liaoceratops
# Couldn't get the pageview data for:  Liaoningosaurus
# Couldn't get the pageview data for:  Liaoningotitan
# Couldn't get the pageview data for:  Liaoningvenator
# Couldn't get the pageview data for:  Libycosaurus
# Couldn't get the pageview data for:  Ligabueino
# Couldn't get the pageview data for:  Ligabuesaurus
# Couldn't get the pageview data for:  Liliensternus
# Couldn't get the pageview data for:  Limaysaurus
# Couldn't get the pageview data for:  Limusaurus
# Couldn't get the pageview data for:  Lingwulong
# Couldn't get the pageview data for:  Lingyuanosaurus
# Couldn't get the pageview data for:  Linhenykus
# Couldn't get the pageview data for:  Linheraptor
# Couldn't get the pageview data for:  Linhevenator
# Couldn't get the pageview data for:  Lirainosaurus
# Couldn't get the pageview data for:  Lisboasaurus
# Couldn't get the pageview data for:  Liubangosaurus
# Couldn't get the pageview data for:  Llukalkan
# Couldn't get the pageview data for:  Lohuecotitan
# Couldn't get the pageview data for:  Loncosaurus
# Couldn't get the pageview data for:  Longisquama
# Couldn't get the pageview data for:  Lophorhothon
# Couldn't get the pageview data for:  Lophostropheus
# Couldn't get the pageview data for:  Lophotrochozoa
# Couldn't get the pageview data for:  Loricatosaurus
# Couldn't get the pageview data for:  Loricosaurus
# Couldn't get the pageview data for:  Losillasaurus
# Couldn't get the pageview data for:  Lourinhanosaurus
# Couldn't get the pageview data for:  Lourinhasaurus
# Couldn't get the pageview data for:  Luanchuanraptor
# Couldn't get the pageview data for:  Lucianosaurus
# Couldn't get the pageview data for:  Lucianovenator
# Couldn't get the pageview data for:  Lufengosaurus
# Couldn't get the pageview data for:  Lukousaurus
# Couldn't get the pageview data for:  Luoyanggia
# Couldn't get the pageview data for:  Lurdusaurus
# Couldn't get the pageview data for:  Lusitanosaurus
# Couldn't get the pageview data for:  Lusotitan
# Couldn't get the pageview data for:  Lusovenator
# Couldn't get the pageview data for:  Lutungutali
# Couldn't get the pageview data for:  Lycorhinus
# Couldn't get the pageview data for:  Lythronax
# Couldn't get the pageview data for:  Macelognathus
# Couldn't get the pageview data for:  Machairasaurus
# Couldn't get the pageview data for:  Machairoceratops
# Couldn't get the pageview data for:  Machimosaurus
# Couldn't get the pageview data for:  Macrocollum
# Couldn't get the pageview data for:  Macrodontophion
# Couldn't get the pageview data for:  Macrogryphosaurus
# Couldn't get the pageview data for:  Macrurosaurus
# Couldn't get the pageview data for:  Magnamanus
# Couldn't get the pageview data for:  Magnapaulia
# Couldn't get the pageview data for:  Magnosaurus
# Couldn't get the pageview data for:  Magyarosaurus
# Couldn't get the pageview data for:  Mahakala omnogovae
# Couldn't get the pageview data for:  Mahuidacursor
# Couldn't get the pageview data for:  Maiasaura
# Couldn't get the pageview data for:  Maip
# Couldn't get the pageview data for:  Majungasaurus
# Couldn't get the pageview data for:  Malarguesaurus
# Couldn't get the pageview data for:  Malawisaurus
# Couldn't get the pageview data for:  Maleevus
# Couldn't get the pageview data for:  Mamenchisaurus
# Couldn't get the pageview data for:  Mandschurosaurus
# Couldn't get the pageview data for:  Manidens
# Couldn't get the pageview data for:  Mansourasaurus
# Couldn't get the pageview data for:  Mantellisaurus
# Couldn't get the pageview data for:  Mapusaurus
# Couldn't get the pageview data for:  Maraapunisaurus
# Couldn't get the pageview data for:  Marasuchus
# Couldn't get the pageview data for:  Marmarospondylus
# Couldn't get the pageview data for:  Marshosaurus
# Couldn't get the pageview data for:  Martharaptor
# Couldn't get the pageview data for:  Masiakasaurus
# Couldn't get the pageview data for:  Massospondylus
# Couldn't get the pageview data for:  Matheronodon
# Couldn't get the pageview data for:  Maxakalisaurus
# Couldn't get the pageview data for:  Mbiresaurus
# Couldn't get the pageview data for:  Medusaceratops
# Couldn't get the pageview data for:  Megalosaurus
# Couldn't get the pageview data for:  Megapnosaurus
# Couldn't get the pageview data for:  Megaraptor
# Couldn't get the pageview data for:  Melanorosaurus
# Couldn't get the pageview data for:  Mendozasaurus
# Couldn't get the pageview data for:  Menefeeceratops
# Couldn't get the pageview data for:  Menucocelsior
# Couldn't get the pageview data for:  Mercuriceratops
# Couldn't get the pageview data for:  Meroktenos
# Couldn't get the pageview data for:  Metriacanthosaurus
# Couldn't get the pageview data for:  Microceratus
# Couldn't get the pageview data for:  Microcoelus
# Couldn't get the pageview data for:  Microhadrosaurus
# Couldn't get the pageview data for:  Micropachycephalosaurus
# Couldn't get the pageview data for:  Microraptor
# Couldn't get the pageview data for:  Microvenator
# Couldn't get the pageview data for:  Mierasaurus
# Couldn't get the pageview data for:  Minmi paravertebra
# Couldn't get the pageview data for:  Minotaurasaurus
# Couldn't get the pageview data for:  Miragaia longicollum
# Couldn't get the pageview data for:  Mirischia
# Couldn't get the pageview data for:  Mnyamawamtuka
# Couldn't get the pageview data for:  Moabosaurus
# Couldn't get the pageview data for:  Mochlodon
# Couldn't get the pageview data for:  Mongolosaurus
# Couldn't get the pageview data for:  Mongolostegus
# Couldn't get the pageview data for:  Monkonosaurus
# Couldn't get the pageview data for:  Monoclonius
# Couldn't get the pageview data for:  Monolophosaurus
# Couldn't get the pageview data for:  Mononykus
# Couldn't get the pageview data for:  Montanoceratops
# Couldn't get the pageview data for:  Morelladon
# Couldn't get the pageview data for:  Morinosaurus
# Couldn't get the pageview data for:  Moros intrepidus
# Couldn't get the pageview data for:  Morrosaurus
# Couldn't get the pageview data for:  Mosaiceratops
# Couldn't get the pageview data for:  Mosasaur
# Couldn't get the pageview data for:  Murusraptor
# Couldn't get the pageview data for:  Mussaurus
# Couldn't get the pageview data for:  Muttaburrasaurus
# Couldn't get the pageview data for:  Muyelensaurus
# Couldn't get the pageview data for:  Mymoorapelta
# Couldn't get the pageview data for:  Naashoibitosaurus
# Couldn't get the pageview data for:  Nambalia
# Couldn't get the pageview data for:  Nankangia
# Couldn't get the pageview data for:  Nanningosaurus
# Couldn't get the pageview data for:  Nanosaurus
# Couldn't get the pageview data for:  Nanshiungosaurus
# Couldn't get the pageview data for:  Nanuqsaurus
# Couldn't get the pageview data for:  Nanyangosaurus
# Couldn't get the pageview data for:  Napaisaurus
# Couldn't get the pageview data for:  Narambuenatitan
# Couldn't get the pageview data for:  Narindasaurus
# Couldn't get the pageview data for:  Nasutoceratops
# Couldn't get the pageview data for:  Navajoceratops
# Couldn't get the pageview data for:  Nebulasaurus
# Couldn't get the pageview data for:  Nedcolbertia
# Couldn't get the pageview data for:  Nedoceratops
# Couldn't get the pageview data for:  Neimongosaurus
# Couldn't get the pageview data for:  Nemegtomaia
# Couldn't get the pageview data for:  Nemegtonykus
# Couldn't get the pageview data for:  Nemegtosaurus
# Couldn't get the pageview data for:  Neosodon
# Couldn't get the pageview data for:  Neovenator
# Couldn't get the pageview data for:  Neuquenraptor
# Couldn't get the pageview data for:  Neuquensaurus
# Couldn't get the pageview data for:  Ngwevu
# Couldn't get the pageview data for:  Nhandumirim
# Couldn't get the pageview data for:  Niebla antiqua
# Couldn't get the pageview data for:  Nigersaurus
# Couldn't get the pageview data for:  Ningyuansaurus
# Couldn't get the pageview data for:  Ninjatitan
# Couldn't get the pageview data for:  Niobrarasaurus
# Couldn't get the pageview data for:  Nipponosaurus
# Couldn't get the pageview data for:  Noasaurus
# Couldn't get the pageview data for:  Nodocephalosaurus
# Couldn't get the pageview data for:  Nodosaurus
# Couldn't get the pageview data for:  Nomingia
# Couldn't get the pageview data for:  Nopcsaspondylus
# Couldn't get the pageview data for:  Normanniasaurus
# Couldn't get the pageview data for:  Notatesseraeraptor
# Couldn't get the pageview data for:  Nothosaur
# Couldn't get the pageview data for:  Nothronychus
# Couldn't get the pageview data for:  Notoceratops
# Couldn't get the pageview data for:  Notocolossus
# Couldn't get the pageview data for:  Notohypsilophodon
# Couldn't get the pageview data for:  Nqwebasaurus
# Couldn't get the pageview data for:  Nullotitan
# Couldn't get the pageview data for:  Nuthetes
# Couldn't get the pageview data for:  Nyasasaurus
# Couldn't get the pageview data for:  Oceanotitan
# Couldn't get the pageview data for:  Ohmdenosaurus
# Couldn't get the pageview data for:  Ojoceratops
# Couldn't get the pageview data for:  Ojoraptorsaurus
# Couldn't get the pageview data for:  Oksoko avarsan
# Couldn't get the pageview data for:  Oligosaurus
# Couldn't get the pageview data for:  Olorotitan
# Couldn't get the pageview data for:  Omeisaurus
# Couldn't get the pageview data for:  Ondogurvel
# Couldn't get the pageview data for:  Oohkotokia
# Couldn't get the pageview data for:  Opisthocoelicaudia
# Couldn't get the pageview data for:  Oplosaurus
# Couldn't get the pageview data for:  Orkoraptor
# Couldn't get the pageview data for:  Ornatops
# Couldn't get the pageview data for:  Ornithodesmus
# Couldn't get the pageview data for:  Ornitholestes
# Couldn't get the pageview data for:  Ornithomerus
# Couldn't get the pageview data for:  Ornithomimoides
# Couldn't get the pageview data for:  Ornithomimus
# Couldn't get the pageview data for:  Ornithopsis
# Couldn't get the pageview data for:  Ornithosuchus
# Couldn't get the pageview data for:  Orodromeus
# Couldn't get the pageview data for:  Orosaurus
# Couldn't get the pageview data for:  Orthogoniosaurus
# Couldn't get the pageview data for:  Orthomerus
# Couldn't get the pageview data for:  Oryctodromeus
# Couldn't get the pageview data for:  Osmakasaurus
# Couldn't get the pageview data for:  Ostafrikasaurus
# Couldn't get the pageview data for:  Ostromia
# Couldn't get the pageview data for:  Ouranosaurus
# Couldn't get the pageview data for:  Overoraptor
# Couldn't get the pageview data for:  Overosaurus
# Couldn't get the pageview data for:  Oviraptor
# Couldn't get the pageview data for:  Owenodon
# Couldn't get the pageview data for:  Oxalaia
# Couldn't get the pageview data for:  Ozraptor
# Couldn't get the pageview data for:  Pachycephalosaurus
# Couldn't get the pageview data for:  Pachyrhinosaurus
# Couldn't get the pageview data for:  Pachysuchus
# Couldn't get the pageview data for:  Padillasaurus
# Couldn't get the pageview data for:  Palaeoctonus
# Couldn't get the pageview data for:  Palaeocursornis
# Couldn't get the pageview data for:  Palaeopteryx
# Couldn't get the pageview data for:  Palaeosaurus
# Couldn't get the pageview data for:  Palaeoscincus
# Couldn't get the pageview data for:  Paludititan
# Couldn't get the pageview data for:  Pampadromaeus
# Couldn't get the pageview data for:  Pamparaptor
# Couldn't get the pageview data for:  Panamericansaurus
# Couldn't get the pageview data for:  Pandoravenator
# Couldn't get the pageview data for:  Panguraptor
# Couldn't get the pageview data for:  Panoplosaurus
# Couldn't get the pageview data for:  Panphagia
# Couldn't get the pageview data for:  Pantydraco
# Couldn't get the pageview data for:  Papiliovenator
# Couldn't get the pageview data for:  Paralitherizinosaurus
# Couldn't get the pageview data for:  Paralititan
# Couldn't get the pageview data for:  Paranthodon
# Couldn't get the pageview data for:  Pararhabdodon
# Couldn't get the pageview data for:  Parasaurolophus
# Couldn't get the pageview data for:  Paraxenisaurus
# Couldn't get the pageview data for:  Pareiasaur
# Couldn't get the pageview data for:  Pareiasaurus
# Couldn't get the pageview data for:  Pareisactus
# Couldn't get the pageview data for:  Parksosaurus
# Couldn't get the pageview data for:  Paronychodon
# Couldn't get the pageview data for:  Parvicursor
# Couldn't get the pageview data for:  Patagonykus
# Couldn't get the pageview data for:  Patagosaurus
# Couldn't get the pageview data for:  Patagotitan
# Couldn't get the pageview data for:  Pawpawsaurus
# Couldn't get the pageview data for:  Pectinodon
# Couldn't get the pageview data for:  Pedopenna
# Couldn't get the pageview data for:  Pegomastax
# Couldn't get the pageview data for:  Peishansaurus
# Couldn't get the pageview data for:  Pelecanimimus
# Couldn't get the pageview data for:  Pellegrinisaurus
# ...
# Couldn't get the pageview data for:  Sinankylosaurus
# Couldn't get the pageview data for:  Sinocalliopteryx
# Couldn't get the pageview data for:  Sinocephale
# Couldn't get the pageview data for:  Sinoceratops
# Couldn't get the pageview data for:  Sinocoelurus
# Couldn't get the pageview data for:  Sinopliosaurus
# Couldn't get the pageview data for:  Sinornithoides
# Couldn't get the pageview data for:  Sinornithomimus
# Couldn't get the pageview data for:  Sinornithosaurus
# Couldn't get the pageview data for:  Sinosauropteryx
# Couldn't get the pageview data for:  Sinosaurus
# Couldn't get the pageview data for:  Sinotyrannus
# Couldn't get the pageview data for:  Sinovenator
# Couldn't get the pageview data for:  Sinraptor
# Couldn't get the pageview data for:  Sinusonasus
# Couldn't get the pageview data for:  Sirindhorna
# Couldn't get the pageview data for:  Skorpiovenator
# Couldn't get the pageview data for:  Smitanosaurus
# Couldn't get the pageview data for:  Sonidosaurus
# Couldn't get the pageview data for:  Sonorasaurus
# Couldn't get the pageview data for:  Soriatitan
# Couldn't get the pageview data for:  Soumyasaurus
# Couldn't get the pageview data for:  Spectrovenator
# Couldn't get the pageview data for:  Sphaerotholus
# Couldn't get the pageview data for:  Sphenosaurus
# Couldn't get the pageview data for:  Sphenosuchia
# Couldn't get the pageview data for:  Sphenosuchus
# Couldn't get the pageview data for:  Spiclypeus
# Couldn't get the pageview data for:  Spicomellus
# Couldn't get the pageview data for:  Spinophorosaurus
# Couldn't get the pageview data for:  Spinops
# Couldn't get the pageview data for:  Spinosaurus
# Couldn't get the pageview data for:  Spinostropheus
# Couldn't get the pageview data for:  Spinosuchus
# Couldn't get the pageview data for:  Spondylosoma
# Couldn't get the pageview data for:  Squalodon
# Couldn't get the pageview data for:  Staurikosaurus
# Couldn't get the pageview data for:  Stegoceras
# Couldn't get the pageview data for:  Stegopelta
# Couldn't get the pageview data for:  Stegosaurides
# Couldn't get the pageview data for:  Stegosaurus
# Couldn't get the pageview data for:  Stegouros
# Couldn't get the pageview data for:  Stellasaurus
# Couldn't get the pageview data for:  Stenonychosaurus
# Couldn't get the pageview data for:  Stenopelix
# Couldn't get the pageview data for:  Stephanosaurus
# Couldn't get the pageview data for:  Stokesosaurus
# Couldn't get the pageview data for:  Streptospondylus
# Couldn't get the pageview data for:  Struthiomimus
# Couldn't get the pageview data for:  Struthiosaurus
# Couldn't get the pageview data for:  Styracosaurus
# Couldn't get the pageview data for:  Succinodon
# Couldn't get the pageview data for:  Suchomimus
# Couldn't get the pageview data for:  Suchoprion
# Couldn't get the pageview data for:  Suchosaurus
# Couldn't get the pageview data for:  Supersaurus
# Couldn't get the pageview data for:  Suskityrannus
# Couldn't get the pageview data for:  Suuwassea
# Couldn't get the pageview data for:  Suzhousaurus
# Couldn't get the pageview data for:  Syngonosaurus
# Couldn't get the pageview data for:  Szechuanosaurus
# Couldn't get the pageview data for:  Tachiraptor
# Couldn't get the pageview data for:  Talarurus
# Couldn't get the pageview data for:  Talenkauen
# Couldn't get the pageview data for:  Tamarro
# Couldn't get the pageview data for:  Tambatitanis
# Couldn't get the pageview data for:  Tangvayosaurus
# Couldn't get the pageview data for:  Tanius
# Couldn't get the pageview data for:  Taniwhasaurus
# Couldn't get the pageview data for:  Tanycolagreus
# Couldn't get the pageview data for:  Tanystropheidae
# Couldn't get the pageview data for:  Tanystropheus
# Couldn't get the pageview data for:  Tanystrosuchus
# Couldn't get the pageview data for:  Taohelong
# Couldn't get the pageview data for:  Tapinocephalus
# Couldn't get the pageview data for:  Tapuiasaurus
# Couldn't get the pageview data for:  Tarascosaurus
# Couldn't get the pageview data for:  Tarbosaurus
# Couldn't get the pageview data for:  Tarchia
# Couldn't get the pageview data for:  Tastavinsaurus
# Couldn't get the pageview data for:  Tatankacephalus
# Couldn't get the pageview data for:  Tatankaceratops
# Couldn't get the pageview data for:  Tataouinea
# Couldn't get the pageview data for:  Tatisaurus
# Couldn't get the pageview data for:  Taurovenator
# Couldn't get the pageview data for:  Taveirosaurus
# Couldn't get the pageview data for:  Tazoudasaurus
# Couldn't get the pageview data for:  Technosaurus
# Couldn't get the pageview data for:  Tecovasaurus
# Couldn't get the pageview data for:  Tehuelchesaurus
# Couldn't get the pageview data for:  Teinurosaurus
# Couldn't get the pageview data for:  Teleocrater
# Couldn't get the pageview data for:  Telmatosaurus
# Couldn't get the pageview data for:  Tendaguria
# Couldn't get the pageview data for:  Tengrisaurus
# Couldn't get the pageview data for:  Tenontosaurus
# Couldn't get the pageview data for:  Teratophoneus
# Couldn't get the pageview data for:  Teratosaurus
# Couldn't get the pageview data for:  Termatosaurus
# Couldn't get the pageview data for:  Terminocavus
# Couldn't get the pageview data for:  Tethyshadros
# Couldn't get the pageview data for:  Texacephale
# Couldn't get the pageview data for:  Texasetes
# Couldn't get the pageview data for:  Thanatotheristes
# Couldn't get the pageview data for:  Thanos simonattoi
# Couldn't get the pageview data for:  Thecocoelurus
# Couldn't get the pageview data for:  Thecodontosaurus
# Couldn't get the pageview data for:  Thecospondylus
# Couldn't get the pageview data for:  Theiophytalia
# Couldn't get the pageview data for:  Therapsid
# Couldn't get the pageview data for:  Therizinosaurus
# Couldn't get the pageview data for:  Theropoda
# Couldn't get the pageview data for:  Thescelosaurus
# Couldn't get the pageview data for:  Thespesius
# Couldn't get the pageview data for:  Tianchisaurus
# Couldn't get the pageview data for:  Tianyulong
# Couldn't get the pageview data for:  Tianyuraptor
# Couldn't get the pageview data for:  Tianzhenosaurus
# Couldn't get the pageview data for:  Tichosteus
# Couldn't get the pageview data for:  Tienshanosaurus
# Couldn't get the pageview data for:  Timimus
# Couldn't get the pageview data for:  Timurlengia
# Couldn't get the pageview data for:  Titanoceratops
# Couldn't get the pageview data for:  Titanosaurus
# Couldn't get the pageview data for:  Tlatolophus
# Couldn't get the pageview data for:  Tochisaurus
# Couldn't get the pageview data for:  Tonganosaurus
# Couldn't get the pageview data for:  Tongtianlong
# Couldn't get the pageview data for:  Tornieria
# Couldn't get the pageview data for:  Torosaurus
# Couldn't get the pageview data for:  Torvosaurus
# Couldn't get the pageview data for:  Tototlmimus
# Couldn't get the pageview data for:  Trachodon
# Couldn't get the pageview data for:  Tralkasaurus
# Couldn't get the pageview data for:  Tratayenia
# Couldn't get the pageview data for:  Traukutitan
# Couldn't get the pageview data for:  Trialestes
# Couldn't get the pageview data for:  Triceratops
# Couldn't get the pageview data for:  Trierarchuncus
# Couldn't get the pageview data for:  Trigonosaurus
# Couldn't get the pageview data for:  Trimucrodon
# Couldn't get the pageview data for:  Trinisaura
# Couldn't get the pageview data for:  Triunfosaurus
# Couldn't get the pageview data for:  Troodon
# Couldn't get the pageview data for:  Tsaagan
# Couldn't get the pageview data for:  Tsagantegia
# Couldn't get the pageview data for:  Tsintaosaurus
# Couldn't get the pageview data for:  Tuebingosaurus
# Couldn't get the pageview data for:  Tugulusaurus
# Couldn't get the pageview data for:  Tuojiangosaurus
# Couldn't get the pageview data for:  Turanoceratops
# Couldn't get the pageview data for:  Turiasaurus
# Couldn't get the pageview data for:  Tylocephale
# Couldn't get the pageview data for:  Tyrannosaurus
# Couldn't get the pageview data for:  Tyrannotitan
# Couldn't get the pageview data for:  Uberabatitan
# Couldn't get the pageview data for:  Ubirajara jubatus
# Couldn't get the pageview data for:  Udanoceratops
# Couldn't get the pageview data for:  Ultrasaurus
# Couldn't get the pageview data for:  Ulughbegsaurus
# Couldn't get the pageview data for:  Unaysaurus
# Couldn't get the pageview data for:  Unenlagia
# Couldn't get the pageview data for:  Unescoceratops
# Couldn't get the pageview data for:  Unquillosaurus
# Couldn't get the pageview data for:  Urbacodon
# Couldn't get the pageview data for:  Utahceratops
# Couldn't get the pageview data for:  Utahraptor
# Couldn't get the pageview data for:  Uteodon
# Couldn't get the pageview data for:  Vagaceratops
# Couldn't get the pageview data for:  Vahiny
# Couldn't get the pageview data for:  Valdoraptor
# Couldn't get the pageview data for:  Valdosaurus
# Couldn't get the pageview data for:  Vallibonavenatrix
# Couldn't get the pageview data for:  Variraptor
# Couldn't get the pageview data for:  Vayuraptor
# Couldn't get the pageview data for:  Vectaerovenator
# Couldn't get the pageview data for:  Vectiraptor
# Couldn't get the pageview data for:  Velafrons
# Couldn't get the pageview data for:  Velocipes
# Couldn't get the pageview data for:  Velociraptor
# Couldn't get the pageview data for:  Velocisaurus
# Couldn't get the pageview data for:  Venaticosuchus
# Couldn't get the pageview data for:  Venenosaurus
# Couldn't get the pageview data for:  Vespersaurus
# Couldn't get the pageview data for:  Veterupristisaurus
# Couldn't get the pageview data for:  Viavenator
# Couldn't get the pageview data for:  Volgatitan
# Couldn't get the pageview data for:  Volkheimeria
# Couldn't get the pageview data for:  Vouivria
# Couldn't get the pageview data for:  Vulcanodon
# Couldn't get the pageview data for:  Wakinosaurus
# Couldn't get the pageview data for:  Walgettosuchus
# Couldn't get the pageview data for:  Wamweracaudia
# Couldn't get the pageview data for:  Wannanosaurus
# Couldn't get the pageview data for:  Weewarrasaurus
# Couldn't get the pageview data for:  Wellnhoferia
# Couldn't get the pageview data for:  Wendiceratops
# Couldn't get the pageview data for:  Wiehenvenator
# Couldn't get the pageview data for:  Willinakaqe
# Couldn't get the pageview data for:  Wintonotitan
# Couldn't get the pageview data for:  Wuerhosaurus
# Couldn't get the pageview data for:  Wulagasaurus
# Couldn't get the pageview data for:  Wulatelong
# Couldn't get the pageview data for:  Wulong bohaiensis
# Couldn't get the pageview data for:  Wyleyia
# Couldn't get the pageview data for:  Xenoceratops
# Couldn't get the pageview data for:  Xenoposeidon
# Couldn't get the pageview data for:  Xenotarsosaurus
# Couldn't get the pageview data for:  Xianshanosaurus
# Couldn't get the pageview data for:  Xiaosaurus
# Couldn't get the pageview data for:  Xiaotingia
# Couldn't get the pageview data for:  Xingtianosaurus
# Couldn't get the pageview data for:  Xingxiulong
# Couldn't get the pageview data for:  Xinjiangovenator
# Couldn't get the pageview data for:  Xinjiangtitan
# Couldn't get the pageview data for:  Xiongguanlong
# Couldn't get the pageview data for:  Xixianykus
# Couldn't get the pageview data for:  Xixiasaurus
# Couldn't get the pageview data for:  Xixiposaurus
# Couldn't get the pageview data for:  Xiyunykus
# Couldn't get the pageview data for:  Xuanhanosaurus
# Couldn't get the pageview data for:  Xuanhuaceratops
# Couldn't get the pageview data for:  Xunmenglong
# Couldn't get the pageview data for:  Xuwulong
# Couldn't get the pageview data for:  Yamaceratops
# Couldn't get the pageview data for:  Yamanasaurus
# Couldn't get the pageview data for:  Yamatosaurus
# Couldn't get the pageview data for:  Yandusaurus
# Couldn't get the pageview data for:  Yangchuanosaurus
# Couldn't get the pageview data for:  Yanornis
# Couldn't get the pageview data for:  Yaverlandia
# Couldn't get the pageview data for:  Yehuecauhceratops
# Couldn't get the pageview data for:  Yi (dinosaur)
# Couldn't get the pageview data for:  Yimenosaurus
# Couldn't get the pageview data for:  Yingshanosaurus
# Couldn't get the pageview data for:  Yinlong
# Couldn't get the pageview data for:  Yixianosaurus
# Couldn't get the pageview data for:  Yizhousaurus
# Couldn't get the pageview data for:  Yongjinglong
# Couldn't get the pageview data for:  Ypupiara
# Couldn't get the pageview data for:  Yuanmousaurus
# Couldn't get the pageview data for:  Yueosaurus
# Couldn't get the pageview data for:  Yulong mini
# Couldn't get the pageview data for:  Yunganglong
# Couldn't get the pageview data for:  Yunmenglong
# Couldn't get the pageview data for:  Yunnanosaurus
# Couldn't get the pageview data for:  Yunyangosaurus
# Couldn't get the pageview data for:  Yurgovuchia
# Couldn't get the pageview data for:  Yutyrannus
# Couldn't get the pageview data for:  Yuxisaurus
# Couldn't get the pageview data for:  Zalmoxes
# Couldn't get the pageview data for:  Zanclodon
# Couldn't get the pageview data for:  Zapalasaurus
# Couldn't get the pageview data for:  Zapsalis
# Couldn't get the pageview data for:  Zaraapelta
# Couldn't get the pageview data for:  Zatomus
# Couldn't get the pageview data for:  Zby
# Couldn't get the pageview data for:  Zephyrosaurus
# Couldn't get the pageview data for:  Zhanghenglong
# Couldn't get the pageview data for:  Zhejiangosaurus
# Couldn't get the pageview data for:  Zhenyuanlong
# Couldn't get the pageview data for:  Zhongjianosaurus
# Couldn't get the pageview data for:  Zhongornis
# Couldn't get the pageview data for:  Zhongyuansaurus
# Couldn't get the pageview data for:  Zhuchengceratops
# Couldn't get the pageview data for:  Zhuchengtitan
# Couldn't get the pageview data for:  Zhuchengtyrannus
# Couldn't get the pageview data for:  Ziapelta
# Couldn't get the pageview data for:  Zigongosaurus
# Couldn't get the pageview data for:  Zizhongosaurus
# Couldn't get the pageview data for:  Zuniceratops
# Couldn't get the pageview data for:  Zuolong
# Couldn't get the pageview data for:  Zuoyunlong
# Couldn't get the pageview data for:  Zupaysaurus
# Couldn't get the pageview data for:  Zuul
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 15>()
#      12     print("Couldn't get the pageview data for: ",i)
#      14 # Obtain the overall dinosaurs data
# ---> 15 df_dinosaurs = pd.concat(df_access)
#
# File ~/opt/anaconda3/envs/data-512-hcd/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/data-512-hcd/lib/python3.10/site-packages/pandas/core/reshape/concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File ~/opt/anaconda3/envs/data-512-hcd/lib/python3.10/site-packages/pandas/core/reshape/concat.py:404, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     401     objs = list(objs)
#     403 if len(objs) == 0:
# --> 404     raise ValueError("No objects to concatenate")
#     406 if keys is None:
#     407     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %% [markdown]
# ### Save the data as excel file for future reference (Temporary)
#
# This is a temporary step which can be neglected.

# %%
# Write the raw data to excel
df_dinosaurs.to_excel('/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/dinosaurs_all.xlsx')
# Read the raw data from excel
df_dinosaurs = pd.read_excel('/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/dinosaurs_all.xlsx')
df_dinosaurs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450788 entries, 0 to 450787
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      450788 non-null  int64
#  1   Unnamed: 0.1    450788 non-null  int64
#  2   index           450788 non-null  int64
#  3   Unnamed: 0.1.1  450788 non-null  int64
#  4   project         450788 non-null  object
#  5   article         450788 non-null  object
#  6   granularity     450788 non-null  object
#  7   timestamp       450788 non-null  int64
#  8   access          450788 non-null  object
#  9   agent           450788 non-null  object
#  10  views           450788 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 37.8+ MB

# %% [markdown]
# ## Step 1c - Load the JSON data into respective files based on access type
#
# **Monthly mobile access - **
# The API separates mobile access types into two separate requests, you will need to sum these to make one count for all mobile pageviews. You should store the mobile access data in a file called:
# dino_monthly_mobile_startYYYYMM-endYYYYMM.json
#
# **Monthly desktop access - ** Monthly desktop page traffic is based on one single request. You should store the desktop access data in a file called:
# dino_monthly_desktop_startYYYYMM-endYYYYMM.json
#
# **Monthly cumulative - ** Monthly cumulative data is the sum of all mobile, and all desktop traffic per article. You should store the monthly cumulative data in a file called:
# dino_monthly_cumulative_startYYYYMM-endYYYYMM.json
#
# For all of the files the startYYYYMM and endYYYYMM represent the starting and ending year and month as integer text.

# %% [markdown]
# ### Function to write the JSON data for each access type

# %%
def write_json(data = df_dinosaurs, access_name = 'desktop'):
  # Aggregate the data for access type mobile
  if access_name == 'mobile':
    columns = data.columns.to_list()
    columns.remove('views')
    data = data.groupby(columns).agg({'views': np.sum}).reset_index()
  
  # Get the cumulative total
  if access_name == 'cumulative':
    data['views'] = data['views'].cumsum()

  result = data.to_json(orient='records')[1:-1].replace('},{', '} {')
  result = '['+result+']'
  result = re.sub("}\s{", "},{", result)
  parsed = json.loads(result)
  json_object = json.dumps(parsed, indent=4)
  # Path to write JSON file
  path = f'''/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/json/dino_monthly_{access_name}_201507-202209.json'''
  with open(path, 'w') as f:
      f.write(json_object)

  print("JSON write complete for access type: ", access_name)

# %% [markdown]
# ### Function to segregate the data into different files based on the access type
#
# Pass the data and segregate into different JSON files

# %%
def process_json(data):
  data.reset_index(inplace=True)
  # Desktop access type
  write_json(data[data['access']=='desktop'].drop(['access', 'Unnamed: 0', 'index'], axis = 1), 'desktop')
  # Mobile access type
  write_json(data[(data['access']=='mobile-app') | (data['access'] == 'mobile-web')].drop(['access', 'Unnamed: 0', 'index'], axis = 1), 'mobile')
  # Cumulative (all-access type)
  write_json(data[data['access']=='all-access'].drop(['access', 'Unnamed: 0', 'index'], axis = 1), 'cumulative')

# %%
# Write the data to the respective JSON files
process_json(df_dinosaurs)
# Out:
# JSON write complete for access type:  desktop
# JSON write complete for access type:  mobile
# JSON write complete for access type:  cumulative

# %% [markdown]
# # Step 2 : Analysis
# You will conduct a very basic visual analysis. The analysis for this homework is to graph specific subsets of the data as a timeseries. You will produce three different graphs.

# %% [markdown]
# ## Step 2a - Maximum Average and Minimum Average
# The first graph should contain time series for the articles that have the highest average page requests and the lowest average page requests for desktop access and mobile access. Your graph should have four lines (max desktop, min desktop, max mobile, min mobile).

# %% [markdown]
# ### Read the JSON files obtained from Step 1
#
# Read the respective JSON files for mobile and desktop access types and load the data into dataframes for further transformation

# %%
# Read the input json files
desktop = open('/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/json/dino_monthly_desktop_201507-202209.json')
mobile = open('/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/json/dino_monthly_mobile_201507-202209.json')

# Load the JSON fiels saved in step 1
json_desktop = json.load(desktop)
json_mobile = json.load(mobile)

# Convert the JSON data into dataframes for further transformation
df_desktop = pd.json_normalize(json_desktop)
df_mobile = pd.json_normalize(json_mobile)
df_desktop.head()
df_mobile.head()
# Out:
#         project        article granularity   timestamp agent  views
# 0  en.wikipedia  Aachenosaurus     monthly  2015070100  user    443
# 1  en.wikipedia  Aachenosaurus     monthly  2015080100  user    412
# 2  en.wikipedia  Aachenosaurus     monthly  2015090100  user    283
# 3  en.wikipedia  Aachenosaurus     monthly  2015100100  user    794
# 4  en.wikipedia  Aachenosaurus     monthly  2015110100  user    311

# %% [markdown]
# ### Function to get the data for articles that have the highest and lowest average page requests over all the months
#
# Steps followed by the function for execution:
#
# 1. Calculate the average of article views over all the available months
# 2. Get the article names with maximum (highest) and minimum (lowest) average views
# 3. Obtain and return the wikipedia data for the above articles with category label

# %%
def max_min_avg(data = None, access = 'desktop'):
  grouped = data.groupby("article").mean('views')
  data['timestamp'] = data['timestamp'].astype('str')
  data['timestamp'] = pd.to_datetime(data['timestamp'], format='%Y%m%d%H')
  # Obtain the articles with maximum and minimum average page requests
  max_name = grouped.loc[grouped['views'].idxmax()].name
  min_name = grouped.loc[grouped['views'].idxmin()].name
  #print(max_name, min_name)
  # Filter the data for the above articles
  data_max = data[data['article'] == max_name][['article', 'timestamp', 'views']]
  data_min = data[data['article'] == min_name][['article', 'timestamp', 'views']]
  # Obtain the label for time series plot
  data_max['category'] = 'max_' + access
  data_max['label'] = data_max['category'] + '[' + data_max['article'] + ']'
  data_min['category'] = 'min_' + access
  data_min['label'] = data_min['category'] + '[' + data_min['article'] + ']'
  data = data_max.append(data_min)
  return data

# %% [markdown]
# ### Obtain the data for both desktop and mobile access type
#
# Pass both the access type labels to the above function. The data returned is then appended to a main dataframe which is used for plotting

# %%
# Obtain the data for time series plots
desktop = max_min_avg(df_desktop, access = 'desktop')
mobile = max_min_avg(df_mobile, access = 'mobile')
# Combine both the access type datasets
df_main = desktop.append(mobile)
df_main = df_main.set_index('timestamp')

# %% [markdown]
# ### Plot the data for the articles with highest and lowest average page views for both desktop and mobile
#
# A total of four time series plots will be generated (two for each access type). All four time series plots are overlapped into a single plot for comparison

# %%
def plot_maxmin(data):
  # Declare the figure size
  plt.figure(figsize=(16, 8), dpi=150)
  # Plot the data values
  df1 = df_main[df_main['category'] == 'max_desktop']
  df1['views'].plot(label=df1['label'].unique()[0], color='orange')
  df2 = df_main[df_main['category'] == 'min_desktop']
  df2['views'].plot(label=df2['label'].unique()[0], color='blue')
  df3 = df_main[df_main['category'] == 'max_mobile']
  df3['views'].plot(label=df3['label'].unique()[0], color='green')
  df4 = df_main[df_main['category'] == 'min_mobile']
  df4['views'].plot(label=df4['label'].unique()[0], color='black')

  # adding title to the plot
  plt.title('Maximum average and Minimum Average')
  # adding Label to the x-axis and y-axis
  plt.xlabel('Month of Visit')
  plt.ylabel('Views')
  # adding legend to the curve
  plt.legend()

  # Save the plot as a png file
  plt.savefig('/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/plots/max_min_average_views.png')

# %% [markdown]
# ### Generate the Plot

# %%
plot_maxmin(df_main)

# %% [markdown]
# ## Step 2b - Top 10 Peak Page Views
# The second graph should contain time series for the top 10 article pages by largest (peak) page views over the entire time by access type. You first find the month for each article that contains the highest (peak) page views, and then order the articles by these peak values. Your graph should contain the top 10 for desktop and top 10 for mobile access (20 lines).

# %% [markdown]
# ### Function to get the articles list that have the top 10 page views across all the months
#
# Steps followed by the function for execution:
#
# 1. Calculate the maximum views across all the months for each article
# 2. Get the top 10 articles that have the largest page views and assign them a rank based on the peak views value
# 3. Obtain and return the wikipedia data for the above top 10 articles with category label

# %%
def top_ten(data = None, access = 'desktop'):
  # Obtain the top 10 articles with largest page views
  grouped = data.groupby("article").max('views').reset_index()
  grouped = grouped.sort_values(by='views', ascending=False)
  # Get the top 10 articles
  top10 = grouped.head(10)
  top10 = top10[['article']].reset_index()
  top10 = top10.drop('index', axis = 1)
  top10['rank'] = pd.Series(np.arange(1,11))
  data['access'] = access
  data = data[['article', 'timestamp', 'views', 'access']]
  # Filter the data for the above articles
  data = data.merge(top10, on='article', how = 'inner', suffixes=('_1', '_2'))
  # Obtain the label for time series plot
  data['category'] = access + '_top_' + data['rank'].astype('str') + '(' + data['article'] +')'
  return data

# %% [markdown]
# ### Obtain the data for both desktop and mobile access type
#
# Pass both the access type labels to the above function. The data returned is then appended to a main dataframe which is used for plotting

# %%
# Obtain the data for time series plots
desktop = top_ten(df_desktop, 'desktop')
mobile = top_ten(df_mobile, 'mobile')
# Combine both the access type datasets
df_main = desktop.append(mobile)
df_main = df_main.set_index('timestamp')

# %% [markdown]
# ### Plot the data for the top 10 articles with highest page views for both desktop and mobile
#
# A total of 20 time series plots will be generated (ten for each access type). All 20 time series plots are overlapped into a single plot for comparison

# %%
def plot_topten(data):
  # Declare the figure size
  plt.figure(figsize=(16, 8), dpi=150)
  
  # Plot the data values
  for i in range(1,10):
    df = data[data['rank'] == i]
    df[df['access'] == 'desktop']['views'].plot(label=df['category'].unique()[0])
    df[df['access'] == 'mobile']['views'].plot(label=df['category'].unique()[1])

  # adding title to the plot
  plt.title('Top 10 Peak Page Views')
  # adding Label to the x-axis and y-axis
  plt.xlabel('Month of Visit')
  plt.ylabel('Views')
  # adding legend to the curve
  plt.legend()

  # Save the plot as a png file
  plt.savefig('/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/plots/top_10_peak_page_views.png')

# %% [markdown]
# ### Generate the Plot

# %%
plot_topten(df_main)

# %% [markdown]
# ## Step 2c - Fewest Months of Data
# The third graph should show pages that have the fewest months of available data. These will all be relatively short time series, some may only have one month of data. Your graph should show the 10 articles with the fewest months of data for desktop access and the 10 articles with the fewest months of data for mobile access.
#
# In order to complete the analysis correctly and receive full credit, your graph will need to be the right scale to view the data; all units, axes, and values should be clearly labeled. Your graph should possess a legend and a title. You must generate a .png or .jpeg formatted image of your final graph.
# You should graph the data using tools or libraries within your notebook, rather than using an external application to facilitate reproducibility.

# %% [markdown]
# ### Function to get the articles list that have the fewest months of available data
#
# Steps followed by the function for execution:
#
# 1. Calculate the count of months with data available for each article
# 2. Get the top 10 articles that have the fewest months of data and assign them a rank based on the count of months with data availability
# 3. Obtain and return the wikipedia data for the above top 10 articles with category label

# %%
def lessfreq_ten(data = None, access = 'desktop'):
  # Obtain the 10 articles with fewest months of data available
  grouped = data.groupby("article").count().reset_index().iloc[:,0:2]
  grouped = grouped.rename(columns={"project": "count"})
  grouped = grouped.sort_values(by='count', ascending=True)
  # Obtain the top 10 articles
  top10 = grouped.head(10)
  top10 = top10[['article']].reset_index()
  top10 = top10.drop('index', axis = 1)
  top10['rank'] = pd.Series(np.arange(1,11))
  data['access'] = access
  data = data[['article', 'timestamp', 'views', 'access']]
  # Filter the data for the above articles
  data = data.merge(top10, on='article', how = 'inner', suffixes=('_1', '_2'))
  # Obtain the label for time series plot
  data['category'] = access + '_least_freq_' + data['rank'].astype('str') + '(' + data['article'] +')'
  return data

# %% [markdown]
# ### Obtain the data for both desktop and mobile access type
#
# Pass both the access type labels to the above function. The data returned is then appended to a main dataframe which is used for plotting

# %%
# Obtain the data for time series plots
desktop = lessfreq_ten(df_desktop, 'desktop')
mobile = lessfreq_ten(df_mobile, 'mobile')
# Combine both the access type datasets
df_main = desktop.append(mobile)
df_main = df_main.set_index('timestamp')

# %% [markdown]
# ### Plot the data for the articles with fewest months of available data
#
# A total of 20 time series plots will be generated (ten for each access type). All 20 time series plots are overlapped into a single plot for comparison.
#
# Note: The data doesn't look complete for all the articles as few articles have the least data avilability.

# %%
def plot_freqten(data):
  # Declare the figure size
  plt.figure(figsize=(16, 8), dpi=150)

  # Plot the data values
  for i in range(1,10):
    df = data[data['rank'] == i]
    df[df['access'] == 'desktop']['views'].plot(label=df['category'].unique()[0])
    df[df['access'] == 'mobile']['views'].plot(label=df['category'].unique()[1])

  # adding title to the plot
  plt.title('Articles with Fewest Months of Data')
  # adding Label to the x-axis and y-axis
  plt.xlabel('Month of Visit')
  plt.ylabel('Views')
  # adding legend to the curve
  plt.legend()

  # Save the plot as a png file
  plt.savefig('/content/drive/MyDrive/MS Admission/Washington/GitHub/DataScienceProjects/data-512-homework_1/plots/articles_with_fewest_months_data.png')

# %% [markdown]
# ### Generate the Plot

# %%
plot_freqten(df_main)
